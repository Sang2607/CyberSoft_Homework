# %%
from Common.FunctionHandle import inputInt
from Common.Decorator import handle_exception

@handle_exception
def TinhUocSo(num):
   listNum = [i for i in range(1,num+1) if num % i == 0]
   print(len(listNum))
   return listNum

@handle_exception
def TinhSoNguyenTo(num):
    totalNums = 0
    for i in range(2,num):
        if num % i == 0:
            totalNums +=1
    return 1 if totalNums == 0 else 0

num = inputInt()
# TinhUocSo(num)
TinhSoNguyenTo(num)

# %%
cart_data = """{ "items": [ {"name": "Áo thun", "price": 200000, "quantity": 2}, {"name": "Quần Jean", "price": 450000, "quantity": 1} ] }"""
cart = json.loads(cart_data)
def  calculate_total(cart_json,discount_percent):
    total = 0
    for i in cart_json["items"]:
        total += (i["price"] * i["quantity"])

    print(f"{total*discount_percent:,}")

discount = float(input())
calculate_total(cart,discount)
# Out:
# 17,000.0
