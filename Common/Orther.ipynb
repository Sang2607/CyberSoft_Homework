# %%
print(f"\n{'='*65}")
print("a","b")

# %%
print(f"\n{'='*65}")
print(f"{'Item list in Warehouse':^65}") #Canh giữa
print(f"{'='*65}")
print(f"{'Product Name':<25}{'Quantity':<12}{'Unit Price':<12}{'Total Amount':<15}")
print(f"{'-'*65}")
# Out:
# ...
#                      Item list in Warehouse
# ...
# Product Name             Quantity    Unit Price  Total Amount
# -----------------------------------------------------------------

# %%
with open(file_json,"w",encoding='utf-8') as f: #ghi là w
    json.dump(song,f,ensure_ascii=False,indent=4) #dump: tạo mới/ghi ra, ensure_ascii: đáp ứng ko bị vỡ, indent thụt vào 4
